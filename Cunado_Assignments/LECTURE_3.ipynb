# %% [markdown]
# **DISCRETE MATHEMATICS II ASSIGNMENT [LECTURE 3]**

# %% [markdown]
# **Name:** Jomar Cuñado <br>
# **Program & Year:** BSCS - 1

# %% [markdown]
# **GRAPH**
#
# A graph is a fundamental mathematical structure used to represent pairwise relations between nodes, called vertices, with their links called edges.

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
graph = nx.Graph()
graph.add_edge(1, 2)
graph.add_node(3)
graph.add_edge(3, 3)
nx.draw_spring(graph, with_labels = True)
plt.title("G")
plt.show()

# %% [markdown]
#  ---

# %% [markdown]
# **DIRECTED GRAPH**
#
# A directed graph is a mathematical structure consisting of nodes, called vertices, connected by arrows, called edges, which have a specific direction from one vertex to another. Each edge has a start vertex and an end vertex, indicating the direction of the relationship.
#
# They can be seen as arrows, an example in the graph below would be, A to D.

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
digra = nx.DiGraph()
digra.add_edge("a", "d")
digra.add_edge("b", "a")
digra.add_edge("c", "b")
digra.add_edge("d", "c")
nx.draw(digra, with_labels = True)
plt.title("Directed Graph")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **SIMPLE GRAPH**
#
# A Simple Graph is an *undirected, unweighted, no multiple edges, and no loops* graph.

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
simgra = nx.Graph()
simgra.add_edge("a", "b")
simgra.add_edge("b", "c")
simgra.add_edge("b", "d")
simgra.add_edge("c", "d")
plt.title("Simple Graph")
nx.draw_spring(simgra, with_labels = True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **COMPLETE GRAPH**
#
# A complete graph is an undirected graph where each pair of distinct vertices is connected by a unique edge. In other words, every vertex is adjacent to every other vertex.

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
comgra = nx.complete_graph(4)
nx.draw_spring(comgra, with_labels = True)
plt.title("Complete Graph")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **BIPARTITE GRAPH**
#
# A Bipartite Graph is a graph in which its vertices are divided into two disjoint and independent sets. Every Vertex in either set is not adjacent to the vertex in the same set, however every edge connects vertices from one set to the other

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
bigra = nx.Graph()
setA = [1, 2, 3, 4]
setB = [7, 8, 9]
bigra.add_nodes_from(setA, bipartite=0)
bigra.add_nodes_from(setB, bipartite=1)
for nodeA in setA:
    for nodeB in setB:
        bigra.add_edge(nodeA, nodeB)
pos = {node: (0, i) for i, node in enumerate(setA)}
pos.update({node: (1, i) for i, node in enumerate(setB)})
nx.draw(bigra, pos, node_color='skyblue', node_size=500, with_labels=True, edge_color='gray', width=1.5)
plt.title("Bipartite Graph")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **SUBGRAPH**
#
# A subgraph is a smaller graph created by choosing certain vertices and edges from the main graph. It represents a subset of the main graph.

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
biggra = nx.Graph()
biggra.add_edge("a", "b")
biggra.add_edge("b", "c")
biggra.add_edge("b", "d")
biggra.add_edge("c", "d")
nx.draw(biggra, with_labels = True)
plt.title("G")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

biggra = nx.Graph()
biggra.add_edge("a", "b")
biggra.add_edge("b", "c")
biggra.add_edge("b", "d")
biggra.add_edge("c", "d")

plt.figure(figsize=(4, 3))
subgra = nx.Graph()
subgra.add_edge("b", "c")
subgra.add_edge("b", "d")
subgra.add_edge("c", "d")
pos = nx.planar_layout(biggra)
nx.draw(subgra, pos, with_labels=True, edge_color='gray', width=1.5)
plt.title("P is a subgraph of G")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 4))
g1 = nx.complete_graph(5)
g2 = nx.complete_graph(4)
g2 = nx.relabel_nodes(g2, {0: "A", 1: "B", 2: "C", 3: "D", 4: "E"})
exgra = nx.from_edgelist([(4, "X"), ("X", "A")])
G = nx.compose_all([g1, g2, exgra])
nx.draw_spring(G, with_labels = True)
plt.title("Main Graph")
plt.show()
print("Degree of each vertex: ")
print(dict(G.degree))
# Out:
# Degree of each vertex:
# {0: 4, 1: 4, 2: 4, 3: 4, 4: 5, 'A': 4, 'B': 3, 'C': 3, 'D': 3, 'X': 2}

# %% [markdown]
# **Degree of each vertex**: <br>
# Let V represent Vertex <br>
# V - Degree <br>
# 0: 4 <br>
# 1: 4 <br>
# 2: 4 <br>
# 3: 4 <br>
# 4: 5 <br>
# 'A': 4 <br>
# 'B': 3 <br>
# 'C': 3 <br>
# 'D': 3 <br>
# 'X': 2 <br>

# %% [markdown]
# **HANDSHAKE THEOREM** <br>
# In any undirected graph, the theorem states that the sum of the degrees of all vertices is always equal to twice the number of edges in the Graph.*italicized text*

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 4))
g1 = nx.complete_graph(5)
g2 = nx.complete_graph(4)
g2 = nx.relabel_nodes(g2, {0: "A", 1: "B", 2: "C", 3: "D", 4: "E"})
exgra = nx.from_edgelist([(4, "X"), ("X", "A")])
G = nx.compose_all([g1, g2, exgra])
nx.draw_spring(G, with_labels = True)
plt.title("Main Graph")
plt.show()
print("Twice number of edges: ")
print(nx.number_of_edges(G) * 2)
degrees = G.degree()
result = sum(deg for node, deg in degrees)
print("Sum of degrees of all vertices: ")
print(result)
# Out:
# Twice number of edges:
# 36
# Sum of degrees of all vertices:
# 36

# %% [markdown]
# **Travelling in a Graph**

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 4))
g1 = nx.complete_graph(5)
g2 = nx.complete_graph(4)
g2 = nx.relabel_nodes(g2, {0: "A", 1: "B", 2: "C", 3: "D", 4: "E"})
exgra = nx.from_edgelist([(4, "X"), ("X", "A")])
G = nx.compose_all([g1, g2, exgra])
nx.draw_spring(G, with_labels = True)
plt.title("Main Graph")
plt.show()

# %% [markdown]
# A **Walk** from vertex 'A' to 1 goes via the edge to X, then to 4, 3, 2, and finally arrives at vertex 1. A → X → 4 → 3 → 2 → 1. <br>
# A **Trail** from vertex 'A' to 3 travels through the edge to X, then to 4, and reaches 3. A → X → 4 → 3. Note that a trail does not include any repeated edge. <br>
# A **Path** from vertex 'A' to 3 goes through the edge to X, then to 4, and arrives at 3. A → X → 4 → 3. Note that a path does not include any repeated vertex. <br>
# A **Closed Walk** from vertex 'A' travels through the edge to X, then to 4, 3, and returns to 'A'. A → X → 4 → 3 → A. Note that a closed walk starts and ends at the same vertex. <br>
# A **Circuit** from vertex 'B' travels through the edge to 'A', then to 'X', and back to 'B'. B → A → X → B. Note that a circuit is a closed trail. <br>
# A **Simple Circuit** from vertex 'X' travels through the edge to 'A', then to 'B', and returns to 'X'. X → A → B → X. Note that a simple circuit is a closed path that starts and ends at the same vertex, without any repeating edges and vertices except for the starting and ending vertex. <br>
#
# ---

# %% [markdown]
# **EULER'S CIRCUIT**
#
# 2 → 4 → 3 → 2 → 0 → 1 →2

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
g = nx.Graph()
g.add_edge(4, 3)
g.add_edge(4, 2)
g.add_edge(3, 2)
g.add_edge(2, 1)
g.add_edge(2, 0)
g.add_edge(1, 0)
nx.draw_spring(g, with_labels = True)
plt.title("Euler's Circuit")
plt.show()

# %% [markdown]
# **EULER'S TRAIL**
#
# 0 → 4 → 5 → 1 → 6 → 5 → 2 → 3 → 7 → 2 → 6 → 3 → 5 → 0

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
G = nx.Graph()
edges = [(0, 4), (4, 5), (5, 1), (1, 6), (6, 5), (5, 2), (2, 3), (3, 7), (7, 2), (2, 6), (6, 3), (3, 5), (5, 0)]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10)
plt.title("Eulerian Trail")
plt.show()

# %% [markdown]
# **HAMILTONIAN'S CIRCUIT**
#
# 0 → 1 → 2 → 3 → 0

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
G = nx.Graph()
edges = [(0, 1), (1, 2), (2, 3), (3, 0), (0, 2), (1, 3)]
G.add_edges_from(edges)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)
plt.title("Hamiltonian Circuit")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
G = nx.Graph()
G.add_edge("A", "B", weight=1.0)
G.add_edge("B", "C", weight=2.0)
G.add_edge("A", "C", weight=3.0)
G.add_edge("A", "D", weight=1.5)
G.add_edge("D", "E", weight=2.5)
G.add_edge("E", "F", weight=0.5)
G.add_edge("B", "F", weight=1.2)
G.add_edge("C", "F", weight=1.7)
G.add_edge("C", "E", weight=0.8)
G.add_edge("F", "A", weight=0.9)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **Travelling Salesman Problem**

# %%
import matplotlib.pyplot as plt
import networkx as nx
G = nx.Graph()
G.add_edge("A", "B", weight=1.0)
G.add_edge("B", "C", weight=2.0)
G.add_edge("A", "C", weight=3.0)
G.add_edge("A", "D", weight=1.5)
G.add_edge("D", "E", weight=2.5)
G.add_edge("E", "F", weight=0.5)
G.add_edge("B", "F", weight=1.2)
G.add_edge("C", "F", weight=1.7)
G.add_edge("C", "E", weight=0.8)
G.add_edge("F", "A", weight=0.9)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()

# %% [markdown]
# <table>
#   <tr>
#     <th>Route</th>
#     <th>Weight</th>
#   </tr>
#   <tr>
#     <td>A → F → B → C → E → D → A</td>
#     <td>8.9</td>
#   </tr>
#   <tr>
#     <td>A → D → E → F → B → C → A</td>
#     <td>10.7</td>
#   </tr>
#   <tr>
#     <td>A → D → E → F → C → B → A</td>
#     <td>9.2</td>
#   </tr>
#   <tr>
#     <td>A → C → B → F → E → D → A</td>
#     <td>10.7</td>
#   </tr>
#   <tr>
#     <td>A → B → C → F → E → D → A</td>
#     <td>9.2</td>
#   </tr>
#   <tr>
#     <td>A → B → F → C → E → D → A</td>
#     <td>8.7</td>
#   </tr>
# </table>

# %% [markdown]
# <br>
# The best route is A → B → F → C → E → D → A
