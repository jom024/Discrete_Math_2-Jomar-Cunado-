# %% [markdown]
# **DISCRETE MATHEMATICS II ASSIGNMENT [LECTURE 4]**

# %% [markdown]
# **Name:** Jomar Cunado<br>
# **Program and Year:** BSCS - 1

# %% [markdown]
# Given the following graph, implement the algorithm in Python.

# %%
import matplotlib.pyplot as plt
import networkx as nx
seed = 55
# Use seed for reproducibility
G = nx.Graph()
plt.figure(figsize=(10, 8))
# Add nodes
G.add_nodes_from(["A","B","C","D","E","F","G"])
# Add self-loops to the remaining nodes
edgelist = [("A","C"),("A","I"),("C","B"),("C","E"),("C","D"),("B","E"),("I","E"),("E","F"),("F","G"),("G","E")]
G.add_edges_from(edgelist)
pos = nx.planar_layout(G)  # Seed for reproducible layout
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels={("A","C"):10,("A","I"):5,("C","B"):20,("C","E"):15,("C","D"):30,("B","E"):25,("I","E"):40,("E","F"):35,("F","G"):50,("G","E"):45},
    font_color='red'
)
nx.draw(G, pos=pos,with_labels=True)
nx.draw(
    G, pos, edge_color='black', width=1, linewidths=1,
    node_size=500, node_color='pink', alpha=0.9,
    with_labels=True)

plt.show()

# %% [markdown]
# **KRUSKAL'S ALGORITHM**

# %%
import matplotlib.pyplot as plt
import networkx as nx
seed = 55
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G", "I"])
edgelist = [("A", "C"), ("A", "I"), ("C", "B"), ("C", "E"), ("C", "D"), ("B", "E"), ("I", "E"), ("E", "F"), ("F", "G"), ("G", "E")]
G.add_edges_from(edgelist)

plt.figure(figsize=(10, 8))
K = nx.Graph()
K.add_nodes_from(G.nodes)
edges = [("A", "I"), ("A", "C"), ("B", "C"), ("C", "D"), ("C", "E"), ("E", "F"), ("E", "G")]
K.add_edges_from(edges)
pos = nx.planar_layout(G)
nx.draw_networkx_edge_labels(
    K, pos,
    edge_labels={("A", "I"):5, ("A", "C"):10, ("B", "C"):20, ("C", "D"):30, ("C", "E"):15, ("E", "F"):35, ("E", "G"):45},
    font_color='purple'
)
nx.draw(
    K, pos=pos, node_color='pink',
    with_labels=True
)

plt.show()

# %% [markdown]
# **Solution**

# %% [markdown]
# <table>
#   <tr>
#     <th>Iteration</th>
#     <th>Edge</th>
#     <th>Weight</th>
#     <th>Action</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>('A', 'I')</td>
#     <td>5</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>('A', 'C')</td>
#     <td>10</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>('C', 'E')</td>
#     <td>15</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>('C', 'B')</td>
#     <td>20</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>('B', 'E')</td>
#     <td>25</td>
#     <td>Not Added</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>('C', 'D')</td>
#     <td>30</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>('E', 'F')</td>
#     <td>35</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>('I', 'E')</td>
#     <td>40</td>
#     <td>Not Added</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>('E', 'G')</td>
#     <td>45</td>
#     <td>Add</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>('G', 'F')</td>
#     <td>50</td>
#     <td>Not Added</td>
#   </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# **PRIM'S ALGORITHM**

# %%
import matplotlib.pyplot as plt
import networkx as nx

seed = 55
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G", "I"])
edgelist = [("A", "C"), ("A", "I"), ("C", "B"), ("C", "E"), ("C", "D"), ("B", "E"), ("I", "E"), ("E", "F"), ("F", "G"), ("G", "E")]
G.add_edges_from(edgelist)

plt.figure(figsize=(10,8))
P = nx.Graph()
P.add_nodes_from(G.nodes)
primdedge = [("A", "I"), ("A", "C"), ("C", "B"), ("C", "D"), ("C", "E"), ("E", "F"), ("E", "G")]
P.add_edges_from(primdedge)
pos = nx.planar_layout(G)
nx.draw_networkx_edge_labels(
    P, pos,
    edge_labels={("A", "I"):5, ("A", "C"):10, ("B", "C"):20, ("C", "D"):30, ("C", "E"):15, ("E", "F"):35, ("E", "G"):45},
    font_color='purple'
)
nx.draw(
    P, pos=pos, node_color='pink',
    with_labels=True
)

plt.show()

# %% [markdown]
# **Solution**

# %% [markdown]
# <table>
#   <tr>
#     <th>Iteration</th>
#     <th>Vertex</th>
#     <th>Edge</th>
#     <th>Weight</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>I</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>A</td>
#     <td>('I', 'A')</td>
#     <td>5</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>C</td>
#     <td>('A', 'C')</td>
#     <td>10</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>E</td>
#     <td>('C', 'E')</td>
#     <td>15</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>B</td>
#     <td>('C', 'B')</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>D</td>
#     <td>('C', 'D')</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>F</td>
#     <td>('E', 'F')</td>
#     <td>35</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>G</td>
#     <td>('E', 'G')</td>
#     <td>45</td>
#   </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# **DIJKTRA'S SHORTEST PATH ALGORITHM**

# %%
import matplotlib.pyplot as plt
import networkx as nx
seed = 55
G = nx.Graph()
G.add_nodes_from(["A", "B", "C", "D", "E", "F", "G", "I"])
edge_list = [("A", "C"), ("A", "I"), ("C", "B"), ("C", "E"), ("C", "D"), ("B", "E"), ("I", "E"), ("E", "F"), ("F", "G"), ("G", "E")]
G.add_edges_from(edge_list)

plt.figure(figsize=(10,8))
D = nx.Graph()
D.add_nodes_from(G.nodes)
D.add_edges_from(G.edges)
pos = nx.planar_layout(G)
nx.draw_networkx_edge_labels(
    D, pos,
    edge_labels={("A", "C"):10, ("A", "I"):5, ("C", "B"):20, ("C", "E"):15, ("C", "D"):30, ("B", "E"):25, ("I", "E"):40, ("E", "F"):35, ("F", "G"):50, ("G", "E"):45},
    font_color='purple'
)

nx.draw_networkx_edges(
    D, pos=pos,
    edgelist=[("A", "C"), ("A", "I"), ("C", "B"), ("C", "E"), ("C", "D"), ("G", "E"), ("E", "F")],
    edge_color='red'
)
nx.draw(
    D, pos=pos, node_color='pink',
    with_labels=True
)

plt.show()

# %% [markdown]
# Shortest Distance from Node A:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>10</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>40</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>25</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>70</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>5</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node B:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>25</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>70</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>35</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node C:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>10</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>20</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>15</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>15</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node D:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>40</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>45</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>80</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>90</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>45</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node E:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>25</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>25</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>15</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>45</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>35</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>45</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>30</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node F:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>80</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>35</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>65</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node G:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>70</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>70</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>60</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>90</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>45</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>75</td>
#   </tr>
# </table>

# %% [markdown]
# Shortest Distance from Node I:

# %% [markdown]
# <table>
#   <tr>
#     <th>Node</th>
#     <th>Lowest Total Weight</th>
#   </tr>
#   <tr>
#     <td>A</td>
#     <td>5</td>
#   </tr>
#   <tr>
#     <td>B</td>
#     <td>35</td>
#   </tr>
#   <tr>
#     <td>C</td>
#     <td>15</td>
#   </tr>
#   <tr>
#     <td>D</td>
#     <td>45</td>
#   </tr>
#   <tr>
#     <td>E</td>
#     <td>30</td>
#   </tr>
#   <tr>
#     <td>F</td>
#     <td>65</td>
#   </tr>
#   <tr>
#     <td>G</td>
#     <td>75</td>
#   </tr>
#   <tr>
#     <td>I</td>
#     <td>0</td>
#   </tr>
# </table>
